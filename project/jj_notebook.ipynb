# %%
import pandas as pd
import plotly.express as px
car_df = pd.read_csv("data/car_data.csv")

#Make a list of what you want to drop
columns_to_drop = ['feature_0', 'feature_1', 'feature_2',
       'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7',
       'feature_8', 'feature_9', 'engine_fuel', 'up_counter']

#Drop the columns using drop()
car_df.drop(columns_to_drop, axis=1, inplace = True) #axis = 1 lets pandas know we are dropping columns, not rows.


#replacing russian with english
car_df["location_region"].replace({"Минская обл.":"Minsk","Гомельская обл.":"Gomel", "Витебская обл.":"Vitebsk", "Брестская обл.":"Brest", "Могилевская обл.":"Mogilev", "Гродненская обл.":"Grodno"}, inplace=True)

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_has_gas     38531 non-null  bool
#  7   engine_type        38531 non-null  object
#  8   engine_capacity    38521 non-null  float64
#  9   body_type          38531 non-null  object
#  10  has_warranty       38531 non-null  bool
#  11  state              38531 non-null  object
#  12  drivetrain         38531 non-null  object
#  13  price_usd          38531 non-null  float64
#  14  is_exchangeable    38531 non-null  bool
#  15  location_region    38531 non-null  object
# ...

# %%
car_df.columns
# Out:
# Index(['manufacturer_name', 'model_name', 'transmission', 'color',
#        'odometer_value', 'year_produced', 'engine_has_gas', 'engine_type',
#        'engine_capacity', 'body_type', 'has_warranty', 'state', 'drivetrain',
#        'price_usd', 'is_exchangeable', 'location_region', 'number_of_photos',
#        'duration_listed'],
#       dtype='object')

# %%
car_df.head(1)
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
#
#    year_produced  engine_has_gas engine_type  engine_capacity  body_type  \
# 0           2010           False    gasoline              2.5  universal
#
#    has_warranty  state drivetrain  price_usd  is_exchangeable location_region  \
# 0         False  owned        all    10900.0            False           Minsk
#
#    number_of_photos  duration_listed
# 0                 9               16

# %%
car_df['manufacturer_name'].value_counts()
# Out:
# Volkswagen       4243
# Opel             2759
# BMW              2610
# Ford             2566
# Renault          2493
# Audi             2468
# Mercedes-Benz    2237
# Peugeot          1909
# Citroen          1562
# Nissan           1361
# Mazda            1328
# Toyota           1246
# Hyundai          1116
# Skoda            1089
# Kia               912
# Mitsubishi        887
# Fiat              824
# Honda             797
# Volvo             721
# ВАЗ               481
# Chevrolet         436
# Chrysler          410
# Seat              303
# Dodge             297
# Subaru            291
# Rover             235
# Suzuki            234
# Daewoo            221
# Lexus             213
# Alfa Romeo        207
# ГАЗ               200
# Land Rover        184
# Infiniti          162
# LADA              146
# Iveco             139
# Saab              108
# Jeep              107
# Lancia             92
# SsangYong          79
# УАЗ                74
# Geely              71
# ...

# %%
car_df['transmission'].value_counts()
# Out:
# mechanical    25633
# automatic     12898
# Name: transmission, dtype: int64

# %%
car_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'odometer_value'}>,
#         <AxesSubplot:title={'center':'year_produced'}>],
#        [<AxesSubplot:title={'center':'engine_capacity'}>,
#         <AxesSubplot:title={'center':'price_usd'}>],
#        [<AxesSubplot:title={'center':'number_of_photos'}>,
#         <AxesSubplot:title={'center':'duration_listed'}>]], dtype=object)

# %%
car_df["engine_type"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='engine_type'>

# %%
"""
numerical_car_df = car_df[['odometer_value', 'duration_listed', 'engine_capacity']]
fig = px.scatter_matrix(numerical_car_df )
fig.show()


fig = px.scatter(car_df, x='odometer_value',y = 'duration_listed',color="model_name",size = "up_counter")
fig.update_layout(
    height = 700,
    width = 1500
)
fig.show()
"""
# Out:
# '\nnumerical_car_df = car_df[[\'odometer_value\', \'duration_listed\', \'engine_capacity\']]\nfig = px.scatter_matrix(numerical_car_df )\nfig.show()\n\n\nfig = px.scatter(car_df, x=\'odometer_value\',y = \'duration_listed\',color="model_name",size = "up_counter")\nfig.update_layout(\n    height = 700,\n    width = 1500\n)\nfig.show()\n'

# %%
#fig = px.bar(x=['pitbull','poodlde'],y=[100,50])
#fig.show()

# %%
#car_df[car_df['manufacturer_name'] == 'Kia']['duration_listed'].max()

# %%
#scatter plot graphs

# %%
fig = px.scatter(car_df, x='manufacturer_name',y = 'duration_listed',color='price_usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(car_df, x='color',y = 'duration_listed',color='transmission')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(car_df, x='body_type',y = 'duration_listed', color = 'engine_type')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(car_df, x='odometer_value',y = 'duration_listed', color = 'year_produced')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(car_df, x='number_of_photos',y = 'duration_listed', color = 'drivetrain')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
